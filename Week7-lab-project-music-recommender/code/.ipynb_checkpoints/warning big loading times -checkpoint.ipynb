# %% [markdown]
# # One step further, for a massive database of songs
# # WARNING: Big loading times zone

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from getpass import getpass
from tqdm.notebook import tqdm
import pandas as pd
import random

# %%
c_id = str(getpass())
# Out:
# ········

# %%
c_s = str(getpass())
# Out:
# ········

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id,
                                                          client_secret=c_s))

# %% [markdown]
# We test that is running properly. We will start taking a list of categories. We test if the calls work

# %% [markdown]
# And we put our categories together

# %%
categories = []
for cat in sp.categories(limit = 50)['categories']['items']:
    categories.append(cat['id'])

# %%
len(categories)
# Out:
# 50

# %%
playlist_id = []
for cat in tqdm(categories):
    try:
        i=0
        cat_data = sp.category_playlists(cat, limit = 50, offset=i)['playlists']['items']
        #Having this while loop will allow retrieve more than 50 per category 
        while len(cat_data) == i+50:
            i +=50
            cat_data += sp.category_playlists(cat, limit = 50, offset=i)['playlists']['items']   
    except:
        continue
    for plist in cat_data:
        try:
            playlist_id.append(plist['id'])
        except:
            continue
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/aapi_heritage_month/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/alternative/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/shows_with_music/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/blackhistorymonth/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/sessions/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/regional_mexican/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/sports/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/popculture/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/radar/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/jre_podcast/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/anime/playlists returned 404 due to Specified id doesn't exist
# HTTP Error for GET to https://api.spotify.com/v1/browse/categories/thirdparty/playlists returned 404 due to Specified id doesn't exist

# %%
len(playlist_id)
# Out:
# 905

# %%
# checkpoint1:saving playlist_id
out_playlist_id = pd.Series(playlist_id, name='playlist_id')
out_playlist_id.to_csv("../data/checkpoints/checkpoint_playlist_id.csv")

# %% [markdown]
# Here we will take all artist ids

# %%
artist_ids = []
for plist in tqdm(playlist_id):
    i = 0
    tracks = sp.playlist_tracks(plist, limit=100, offset=i)['items']
    while len(tracks)==i+100:
        i += 100
        tracks += sp.playlist_tracks(plist, limit=100, offset=i)['items']
    for track in tracks:
        try:
            for ids in [artist['id'] for artist in track['track']['artists']]:
                artist_ids.append(ids)
        except:
            continue
# Out:
#   0%|          | 0/858 [00:00<?, ?it/s]

# %% [markdown]
# Removing duplicated ids

# %%
artist_ids = list(set(artist_ids))
print(len(artist_ids))
# Out:
# 29944

# %%
# checkpoint2:saving artist_ids
out_artist_ids = pd.Series(artist_ids, name='artist_ids')
out_artist_ids.to_csv("checkpoint_artist_ids.csv")

# %%
# To recall the dataframe 
# call = pd.read_csv("checkpoint_artist_ids.csv",index_col=0)
# call
# Out:
#                    artist_ids
# 0      5WId4o5jdGVhptNU0uqKxu
# 1      1RPAAHsStLojK33L7zhgzl
# 2      2ISweDneTd9LZ99oeuzl82
# 3      2OxHUuZT8RnLcPEqiQDUFw
# 4      39FC9x5PaTNYHp5hwlaY4q
# ...                       ...
# 29939  2SHZD4a3ioptZ3USCc2LKQ
# 29940  62CcVzIaV3dNGEmE12YAL9
# 29941  6uZcG9ex8hJKEo3XUyMxEX
# 29942  1VoKwUAdCduhJQqJMIUHtW
# 29943  5yQd0LJ7Xwb31XIIAw354J
#
# [29944 rows x 1 columns]

# %% [markdown]
# And shuffle the list to reduce bias from the sample recovered. If it is not shuffled, the playlists from certain category would be taken first and the categories towards the end, as this script takes a lot of time to complete, won't be considered. This way we can run the script to gather as much data as we can in the period of time, and will be tracks from random artists instead of the ones from certain category.

# %%
random.shuffle(artist_ids)

# %% [markdown]
# Now we get a list of all their albums

# %%
album_ids = []

for artist in tqdm(artist_ids):
        i = 0
        albums = sp.artist_albums(artist, limit=50, offset=i)['items']
        while len(albums)==i+50:
            i += 50
            albums += sp.artist_albums(artist, limit=50, offset=i)['items']
        for album in albums:
            album_ids.append(album['id'])
# Out:
#   0%|          | 0/29944 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2e52564b2c91> in <module>
#       6         while len(albums)==i+50:
#       7             i += 50
# ----> 8             albums += sp.artist_albums(artist, limit=50, offset=i)['items']
#       9         for album in albums:
#      10             album_ids.append(album['id'])
#
# ~\anaconda3\envs\excondables\lib\site-packages\spotipy\client.py in artist_albums(self, artist_id, album_type, country, limit, offset)
#     384
#     385         trid = self._get_id("artist", artist_id)
# --> 386         return self._get(
#     387             "artists/" + trid + "/albums",
#     388             album_type=album_type,
#
# ~\anaconda3\envs\excondables\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\anaconda3\envs\excondables\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     238
#     239         try:
# --> 240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
#     242                 timeout=self.requests_timeout, **args
#
# ~\anaconda3\envs\excondables\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\envs\excondables\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\excondables\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\envs\excondables\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\envs\excondables\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\excondables\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\excondables\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\excondables\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\envs\excondables\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\envs\excondables\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\envs\excondables\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\envs\excondables\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\excondables\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Again, removing duplicates

# %%
len(album_ids)
# Out:
# 4689

# %%
album_ids = list(set(album_ids))
len(album_ids)
# Out:
# 4682

# %%
# checkpoint2:saving artist_ids
out_album_ids = pd.Series(album_ids, name='album_ids')
out_album_ids.to_csv("checkpoint_album_ids.csv")

# %%
random.shuffle(album_ids)

# %% [markdown]
# Going through every album and extracting the track information

# %%
song_id = []
song_name = []
song_artists = []



for album in tqdm(album_ids):
    try:
        tracks = sp.album_tracks(album)['items']            
    except:
        continue
    for track in tracks:
        song_id.append(track['id'])
        song_name.append(track['name'])
        song_artists.append([artist['name'] for artist in track['artists']])
# Out:
#   0%|          | 0/4682 [00:00<?, ?it/s]

# %% [markdown]
# Creating a pandas dataframe, and dropping duplicates, if the same track was in several albums

# %%
data = {'id':song_id,
        'name':song_name,
        'artists':song_artists
        }
songs = pd.DataFrame(data=data)
songs
# Out:
#                            id  \
# 0      2egHxtlaL9Pd6m9NFb4llP
# 1      0R89Wl9baCQPk25VC2gHWl
# 2      4HiRRvtoF3ELp1pKCD3lVK
# 3      6M4bO0CW6XpBMAhlVQCi6G
# 4      6CixyJENxnhPZIWh9G1M67
# ...                       ...
# 98740  6BS6bgNpNsKenX7cu84syL
# 98741  00CtwxkEQh21vP7HUIFbDi
# 98742  1mT2Hv4RlZk4h3O7qytIZ6
# 98743  53lgmH7IQNN9L1aOa5QMaL
# 98744  7I7VcNZdZPKEmIz4nlRJqI
#
#                                                     name  \
# 0                         Brettl-Lieder: No. 6, Galathea
# 1                       Brettl-Lieder: No. 7, Gigerlette
# 2          Brettl-Lieder: No. 1, Der genügsame Liebhaber
# 3                 Brettl-Lieder: No. 2, Einfältiges Lied
# 4                          Brettl-Lieder: No. 5, Mahnung
# ...                                                  ...
# 98740           Spanish Dances, Op. 23: No. 2. Zapateado
# 98741      Sonata in E Minor, No. 8: I. Preludio: Adagio
# 98742  Sonata in E Minor, No. 8: II. Allemanda: Alleg...
# 98743  Sonata in E Minor, No. 8: III. Sarabanda: Larg...
# 98744        Sonata in E Minor, No. 8: IV. Giga: Allegro
#
#                                                  artists
# 0      [Arnold Schoenberg, Thomas Ebenstein, Charles ...
# 1      [Arnold Schoenberg, Thomas Ebenstein, Charles ...
# 2      [Arnold Schoenberg, Thomas Ebenstein, Charles ...
# 3      [Arnold Schoenberg, Thomas Ebenstein, Charles ...
# 4      [Arnold Schoenberg, Thomas Ebenstein, Charles ...
# ...                                                  ...
# 98740   [Pablo de Sarasate, Ossy Renardy, Walter Robert]
# 98741     [Arcangelo Corelli, Ossy Renardy, Leo Taubman]
# 98742     [Arcangelo Corelli, Ossy Renardy, Leo Taubman]
# 98743     [Arcangelo Corelli, Ossy Renardy, Leo Taubman]
# 98744     [Arcangelo Corelli, Ossy Renardy, Leo Taubman]
#
# [98745 rows x 3 columns]

# %%
songs = songs.drop_duplicates(subset='id')
songs.reset_index(drop=True, inplace=True)

# %%
# checkpoint:saving songs
songs.to_csv("songs.csv")

# %%
def chunks(lst,n):
    """
    Yields n-sized chunks of lst
    """
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

# %%
song_ids = songs['id']
audio_feats = []
for chunk in tqdm(list(chunks(song_ids,50))):
    try:
        audio_feats.append(sp.audio_features(chunk))
    except:
        continue
# Out:
#   0%|          | 0/1975 [00:00<?, ?it/s]

# %% [markdown]
# we flatten this list into one long list of dictionaries, and turn it into a series, in order to use pandas.dropna(, so the conversion to data frame can easily work

# %%
audio_feats = pd.Series([y for x in audio_feats for y in x], name='features')

# %%
feat_df = pd.DataFrame(list(audio_feats.dropna()))

# %%
# checkpoint:saving features
feat_df.to_csv("feat_df.csv")

# %%
final = songs.merge(feat_df, on = 'id')

# %% [markdown]
# We test that the merge worked properly using a random sample of 50, taking the audio features again, and comparing the value of danceability, for example in the resulting dataframe. The next cell will return true if there are matches, false if not

# %%
sample = final.sample(50).reset_index()
(pd.DataFrame(sp.audio_features(sample['id']))['danceability'] == sample['danceability']).value_counts()
# Out:
# True    50
# Name: danceability, dtype: int64

# %%
final.sample(50)
# Out:
#                            id  \
# 976    6Nmn1cVJhsLbs4pBAZ2BY8
# 50665  4rSwiQS4TLeJG58zbPBzE3
# 15995  1NcJjyfkeuig1MnbyfxCYE
# 3038   7oOjTyknagNQ9nA5geqtys
# 70399  69x9IlSsugdAkslQLeADH4
# 69111  0WRM8GXBuANkzTdYOyMWIy
# 45197  7CuvT0VKMYUhXkOTWmfwKt
# 15991  1UbUdY3K27RiOiiTLyb4xR
# 13533  0ywzvKSdn6dDtqfKy9ZBku
# 60396  007uw7kPNVDe46Rj1olfJR
# 67818  6q8PZZxuq9wMbOyVkFc8dC
# 20852  5UcjqGyanoeJF75v6lYomC
# 76883  6Az9htsBDd5Q911rI91cQ9
# 97621  35fWfsiIZJrbn71hq39PbG
# 50123  0kLcTDAOu0PSPF0Guhd7zt
# 78481  6Sdrttx61LBwBUKnVy9gRk
# 20835  4yEUIdxEQ49OROofuGX2oo
# 34914  518Q5Mm1F6KeAWcb4ItXKm
# 75958  6L3khoyFdxHBiKqnei8XNj
# 4382   66PmiQdUaVH0WOktjxEfji
# 85773  5m4LN1FSEenMhdxVDwHfNq
# 71324  4IWCGf2UQK9ioo6SJdiq8o
# 6926   3LzzEqRMLHXKYE9m8WrDd0
# 94771  3rIJMxxvKZKvZgeMZNlijD
# 14108  01fVE2CffODpBnmtEWQkY3
# 79931  359qfGOJZR375PcxJpAD3O
# 61521  4CFxvyDNN4kX6IHdHwG5X9
# 35305  4iVp625223ptHWC8hU6jET
# 20191  60GavHXmKGAFcUkiCecNlk
# 58079  30UIlVHgzGN22lZTB7MFf2
# 85218  1o64WXqrYicdu0JRmsOQnv
# 58044  2AZwuGX5cOD79S3AnYkVCg
# 34736  7pKsZEgiE0EALIkXLITMGB
# 1369   2t4dxtekpdKzf1cKKDZGyl
# 40602  4rEvBfaUWUCr748K55rUea
# 82336  7jBlXoHvm1WbeuPHXBNDzK
# 88490  5GB8Piwt3xeI6sVbx8GWEr
# 87865  3xz4EbKevbtCsYAUsvmwkO
# 83973  3ka3ItUDMPQ9JxLpHkCcS6
# 78950  3kp0NEFrEWqOsBumdfnhL4
# 63613  0FJldC1mxvIAjH313qe84r
# 28534  1NvljRaADQepKNBy6qdv2G
# 15456  5quBJbvbJp9tC1lJ7qPO4E
# 6271   0NwB4eBTT7Va9o6FIuoRq4
# 31798  1y0Vz0VAhTbaIoyTVFdTZj
# 92127  4SOKGIyWMKaiRxq0Dh17x7
# 63658  40gUGv4FpZciajDmRy0LgN
# 91370  6oJaAjDz59ILY7uONvRXDc
# 34131  5heigNtyFnPefoicDBJHXB
# 4915   0Jhh2jduuHNGR4AfbqFRCC
#
#                                                     name  \
# 976    Sonata for Violin and Guitar in D Major: III. ...
# 50665                                             Cereza
# 15995  Water Music: Suite No. 1 in F Major, HWV 348: ...
# 3038                                              Africa
# 79931          0.000000    0.0577   0.7660  110.245  audio_features
# 61521          0.000056    0.1720   0.7010   99.036  audio_features
# 35305          0.868000    0.6300   0.2410  134.192  audio_features
# 20191          0.000000    0.2320   0.8160  171.904  audio_features
# 58079          0.000000    0.1180   0.6400  182.064  audio_features
# 85218          0.000335    0.0569   0.7880  129.895  audio_features
# 58044          0.285000    0.1520   0.6060  129.932  audio_features
# 34736          0.001650    0.0753   0.8790  192.587  audio_features
# 1369           0.000000    0.1040   0.9610  180.030  audio_features
# 40602          0.001560    0.0763   0.9400  129.768  audio_features
# 82336          0.010700    0.0804   0.1060   85.479  audio_features
# 88490          0.000000    0.2660   0.9630  103.013  audio_features
# 87865          0.000362    0.0721   0.5260   92.051  audio_features
# 83973          0.000012    0.0510   0.6720  188.136  audio_features
# 78950          0.000000    0.2260   0.6470  167.987  audio_features
# 63613          0.000068    0.1870   0.8040  170.211  audio_features
# 28534          0.677000    0.0622   0.1910   84.250  audio_features
# 15456          0.905000    0.0853   0.1510   97.885  audio_features
# 6271           0.349000    0.0300   0.7730  123.994  audio_features
# 31798          0.888000    0.2290   0.3860  139.887  audio_features
# 92127          0.000034    0.2190   0.9040   97.045  audio_features
# 63658          0.908000    0.1080   0.2730   72.823  audio_features
# 91370          0.824000    0.1850   0.4750  171.598  audio_features
# 34131          0.921000    0.1990   0.0921  121.005  audio_features
# 4915           0.000014    0.1440   0.7680   84.340  audio_features
#
#                                         uri  \
# 976    spotify:track:6Nmn1cVJhsLbs4pBAZ2BY8
# 50665  spotify:track:4rSwiQS4TLeJG58zbPBzE3
# 15995  spotify:track:1NcJjyfkeuig1MnbyfxCYE
# 3038   spotify:track:7oOjTyknagNQ9nA5geqtys
# 70399  spotify:track:69x9IlSsugdAkslQLeADH4
# 69111  spotify:track:0WRM8GXBuANkzTdYOyMWIy
# 45197  spotify:track:7CuvT0VKMYUhXkOTWmfwKt
# 15991  spotify:track:1UbUdY3K27RiOiiTLyb4xR
# 13533  spotify:track:0ywzvKSdn6dDtqfKy9ZBku
# 60396  spotify:track:007uw7kPNVDe46Rj1olfJR
# 67818  spotify:track:6q8PZZxuq9wMbOyVkFc8dC
# 20852  spotify:track:5UcjqGyanoeJF75v6lYomC
# 76883  spotify:track:6Az9htsBDd5Q911rI91cQ9
# 97621  spotify:track:35fWfsiIZJrbn71hq39PbG
# 50123  spotify:track:0kLcTDAOu0PSPF0Guhd7zt
# 78481  spotify:track:6Sdrttx61LBwBUKnVy9gRk
# 20835  spotify:track:4yEUIdxEQ49OROofuGX2oo
# 34914  spotify:track:518Q5Mm1F6KeAWcb4ItXKm
# 75958  spotify:track:6L3khoyFdxHBiKqnei8XNj
# 4382   spotify:track:66PmiQdUaVH0WOktjxEfji
# 85773  spotify:track:5m4LN1FSEenMhdxVDwHfNq
# 71324  spotify:track:4IWCGf2UQK9ioo6SJdiq8o
# 6926   spotify:track:3LzzEqRMLHXKYE9m8WrDd0
# 94771  spotify:track:3rIJMxxvKZKvZgeMZNlijD
# 14108  spotify:track:01fVE2CffODpBnmtEWQkY3
# 78481  https://api.spotify.com/v1/audio-analysis/6Sdr...       214680
# 20835  https://api.spotify.com/v1/audio-analysis/4yEU...       233067
# 34914  https://api.spotify.com/v1/audio-analysis/518Q...       159188
# 75958  https://api.spotify.com/v1/audio-analysis/6L3k...        86253
# 4382   https://api.spotify.com/v1/audio-analysis/66Pm...       482000
# 85773  https://api.spotify.com/v1/audio-analysis/5m4L...       174040
# 71324  https://api.spotify.com/v1/audio-analysis/4IWC...       139200
# 6926   https://api.spotify.com/v1/audio-analysis/3Lzz...       229333
# 94771  https://api.spotify.com/v1/audio-analysis/3rIJ...       145324
# 14108  https://api.spotify.com/v1/audio-analysis/01fV...       313227
# 79931  https://api.spotify.com/v1/audio-analysis/359q...       231720
# 61521  https://api.spotify.com/v1/audio-analysis/4CFx...       207853
# 35305  https://api.spotify.com/v1/audio-analysis/4iVp...       198053
# 20191  https://api.spotify.com/v1/audio-analysis/60Ga...       154013
# 58079  https://api.spotify.com/v1/audio-analysis/30UI...       177013
# 85218  https://api.spotify.com/v1/audio-analysis/1o64...       158596
# 58044  https://api.spotify.com/v1/audio-analysis/2AZw...       160907
# 34736  https://api.spotify.com/v1/audio-analysis/7pKs...       232507
# 1369   https://api.spotify.com/v1/audio-analysis/2t4d...       206520
# 40602  https://api.spotify.com/v1/audio-analysis/4rEv...       272160
# 82336  https://api.spotify.com/v1/audio-analysis/7jBl...       183613
# 88490  https://api.spotify.com/v1/audio-analysis/5GB8...       155825
# 87865  https://api.spotify.com/v1/audio-analysis/3xz4...       279987
# 83973  https://api.spotify.com/v1/audio-analysis/3ka3...       181040
# 78950  https://api.spotify.com/v1/audio-analysis/3kp0...       235360
# 63613  https://api.spotify.com/v1/audio-analysis/0FJl...       231080
# 28534  https://api.spotify.com/v1/audio-analysis/1Nvl...       252760
# 15456  https://api.spotify.com/v1/audio-analysis/5quB...       517920
# 6271   https://api.spotify.com/v1/audio-analysis/0NwB...       419758
# 31798  https://api.spotify.com/v1/audio-analysis/1y0V...        73000
# 92127  https://api.spotify.com/v1/audio-analysis/4SOK...       149467
# 63658  https://api.spotify.com/v1/audio-analysis/40gU...       421920
# 91370  https://api.spotify.com/v1/audio-analysis/6oJa...       119187
# 34131  https://api.spotify.com/v1/audio-analysis/5hei...       358027
# 4915   https://api.spotify.com/v1/audio-analysis/0Jhh...       287794
#
#        time_signature
# 976                 4
# 50665               4
# 15995               4
# 3038                4
# 70399               4
# 69111               4
# 45197               4
# 15991               4
# 13533               5
# 60396               4
# 67818               5
# 20852               4
# 76883               4
# 97621               4
# 50123               4
# 78481               4
# 20835               4
# 34914               4
# 75958               4
# 4382                4
# 85773               4
# 71324               4
# 6926                3
# 94771               4
# 14108               3
# 79931               4
# 61521               4
# 35305               4
# 20191               4
# 58079               4
# 85218               4
# 58044               4
# 34736               4
# 1369                4
# 40602               4
# 82336               3
# 88490               4
# 87865               4
# 83973               4
# 78950               4
# 63613               4
# 28534               3
# 15456               4
# 6271                4
# 31798               3
# 92127               4
# 63658               4
# 91370               3
# 34131               3
# 4915                4

# %%
final.to_csv("Final dataframe.csv")
