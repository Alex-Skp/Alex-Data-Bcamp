# %%
import numpy as np

# %%
data = np.random.randn (100,100,100)

# %%
# %timeit
# Out:
# array([[[ 1.95751922,  1.79491927,  0.6052331 , ...,  1.43917793,
#           0.9914683 ,  0.33152762],
#         [ 0.23387721,  0.01409203,  0.76813382, ..., -0.19614404,
#           0.40159789, -0.7464033 ],
#         [-0.37659633,  1.10382707,  1.682435  , ...,  0.02051301,
#          -1.20404998, -0.97813417],
#         ...,
#         [ 1.70467645,  1.07276109,  0.24519994, ..., -0.23917355,
#           0.04229999, -0.98240333],
#         [-1.5863341 ,  0.08898484, -1.65758059, ...,  0.48456162,
#           0.45296478, -0.57604845],
#         [ 0.71642145, -0.91474534,  0.07236754, ...,  0.88772909,
#           0.46895325, -0.38754237]],
#
#        [[-0.54908378,  1.02832689, -0.19498898, ...,  0.36298163,
#           0.8015833 ,  0.13787347],
#         [ 0.48509237, -0.25667231, -0.88018245, ...,  0.535747  ,
#          -1.50577125,  0.42233031],
#         [-0.78941415,  1.70391439, -0.0308057 , ..., -0.09523101,
#          -1.60658068, -1.64556506],
#         ...,
# ...
