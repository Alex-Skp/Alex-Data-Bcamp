# %% [markdown]
# # Mark, My dearest friend
#
# This jupyter notebook will shine a little bit of light over my friend Mark.

# %% [markdown]
# 1.[Mark](#Mark)
# 2.[Mark, in all his glory](#Mark,-in-all-his-glory)
# 3.[Mark's Ideal Holiday Plans](#Mark's-Ideal-Holiday-Plans)
# 4.[Call To Action](#Call-to-action)

# %% [markdown]
# ## Mark

# %% [markdown]
# **Mark** loves to travel, but lockdowns will never stop, and brought up the worst from him, so he decided to stay at home, buy a brand new TV on Amazon and watch all of the lord of the rings movies throughout the weekend.

# %% [markdown]
# ## Mark, in all his glory

# %% [markdown]
# ![title](foto.jpg)

# %% [markdown]
# ## Mark's Ideal Holiday Plans

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('4S9-vDow2d0')

# %% [markdown]
# ## <font color=#fb3309 > Call To Action </font>

# %%
import time 
name = input("Please enter your name: ")
time.sleep(1)
print("Okay, ",name,". This is what we are going to do:")
time.sleep(.5)
plan = input("Where would you bring Mark to, for a vacation together? ")
time.sleep(1)
print("Right! That seems good, now take the phone, and call Mark to tell him to move his ass out of the couch, and bring him over to ",plan," Together!")
# Out:
# Please enter your name: maria
# Okay,  maria . This is what we are going to do:
# Where would you bring Mark to, for a vacation together? leave
# Right! That seems good, now take the phone, and call Mark to tell him to move his ass out of the couch, and bring him over to  leave  Together!
