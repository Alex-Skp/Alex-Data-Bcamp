# %% [markdown]
# # Before you start:
# - Read the SQLtoPython.md file and use the resources in the SQLtoPython.md file
# - Happy learning!

# %%
import numpy as np
import pandas as pd
import pymysql 
from sqlalchemy import create_engine

# %% [markdown]
# # Challenge 1 - Load and Evaluate the Datasets
#
# #### In this challenge we will load two SQL tables from [this link](https://relational.fit.cvut.cz/dataset/Stats). We will then proceed to evaluate the data to see what type of cleaning and manipulation is necessary.
#
# In the cell below, create a mysql engine using the link provided above.

# %%
engine= create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats')

# %% [markdown]
# Use this connection to load the `users` table. Load this table into a variable called `users`.

# %%
users= pd.read_sql_query('Select * from users', engine )

# %% [markdown]
# #### Let's start examining the dataset.
#
# First look at the first five rows using the `head` function.

# %%
users.head()
# Out:
#    Id  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0  -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1   2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2   3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3   4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4   5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
# 2  <p><a href="http://blog.stackoverflow.com/2009...     22       19
# 3  <p>currently at a startup in SF</p>\n\n<p>form...     11        0
# 4  <p>Quantitative researcher focusing on statist...   1145      662
#
#    DownVotes  AccountId   Age                     ProfileImageUrl
# 0       1920         -1   NaN                                None
# 1          0          2  37.0                                None
# 2          0          3  35.0                                None
# 3          0       1998  28.0  http://i.stack.imgur.com/d1oHX.jpg
# 4          5      54503  35.0                                None

# %% [markdown]
# Next, examine the column names and types to see if there is a type mismatch. Use the `dtypes` function.

# %%
users.dtypes
# Out:
# Id                          int64
# Reputation                  int64
# CreationDate       datetime64[ns]
# DisplayName                object
# LastAccessDate     datetime64[ns]
# WebsiteUrl                 object
# Location                   object
# AboutMe                    object
# Views                       int64
# UpVotes                     int64
# DownVotes                   int64
# AccountId                   int64
# Age                       float64
# ProfileImageUrl            object
# dtype: object

# %% [markdown]
# Finally, we'll examine the `describe` function to see the descriptive statistics for the numeric variables.

# %%
users.describe()
# Out:
#                  Id    Reputation         Views       UpVotes     DownVotes  \
# count  40325.000000  40325.000000  40325.000000  40325.000000  40325.000000
# mean   28037.399727     84.078735      8.909634      6.587452      0.260905
# std    16323.402785    791.426513    154.273963    134.493655     11.252922
# min       -1.000000      1.000000      0.000000      0.000000      0.000000
# 25%    12971.000000      1.000000      0.000000      0.000000      0.000000
# 50%    28042.000000     11.000000      0.000000      0.000000      0.000000
# 75%    42549.000000    101.000000      3.000000      0.000000      0.000000
# max    55747.000000  87393.000000  20932.000000  11442.000000   1920.000000
#
#           AccountId          Age
# count  4.032500e+04  8318.000000
# mean   2.032547e+06    31.642582
# std    1.571884e+06     9.294174
# min   -1.000000e+00    13.000000
# 25%    4.578670e+05    26.000000
# 50%    1.816441e+06    30.000000
# 75%    3.357012e+06    35.000000
# max    5.027354e+06    94.000000

# %% [markdown]
# #### Now let's load the posts table in the cell below.
#
# Use the same mysql engine to load the posts table into a dataframe called `posts`.

# %%
posts= pd.read_sql_query('Select * from posts', engine )

# %% [markdown]
# #### Let's repeat what we did with the `users` table and print the first 5 rows, the data types of each column and describe the numeric data.
#
# Do this in the following 3 cells below.

# %%
posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0   1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#       LasActivityDate                                              Title  ...  \
# 0 2010-09-15 21:08:26                      Eliciting priors from experts  ...
# 1 2012-11-12 09:21:54                                 What is normality?  ...
# 2 2013-05-27 14:48:36  What are some valuable Statistical Analysis op...  ...
# 3 2010-09-08 03:00:19  Assessing the significance of differences in d...  ...
# 4 2010-07-19 19:21:15                                               None  ...
#
#   AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# 0         5.0             1           14.0               NaN
# 1         7.0             1            8.0              88.0
# 2        19.0             4           36.0             183.0
# 3         5.0             2            2.0               NaN
# 4         NaN             3            NaN              23.0
#
#          LastEditDate  CommunityOwnedDate ParentId  ClosedDate  \
# 0                 NaT                 NaT      NaN         NaT
# 1 2010-08-07 17:56:44                 NaT      NaN         NaT
# 2 2011-02-12 05:50:03 2010-07-19 19:13:28      NaN         NaT
# 3                 NaT                 NaT      NaN         NaT
# 4 2010-07-19 19:21:15 2010-07-19 19:14:43      3.0         NaT
#
#   OwnerDisplayName LastEditorDisplayName
# 0             None                  None
# 1             None                  None
# 2             None                  None
# 3             None                  None
# 4             None                  None
#
# [5 rows x 21 columns]

# %%
posts.dtypes
# Out:
# Id                                int64
# PostTypeId                        int64
# AcceptedAnswerId                float64
# CreaionDate              datetime64[ns]
# Score                             int64
# ViewCount                       float64
# Body                             object
# OwnerUserId                     float64
# LasActivityDate          datetime64[ns]
# Title                            object
# Tags                             object
# AnswerCount                     float64
# CommentCount                      int64
# FavoriteCount                   float64
# LastEditorUserId                float64
# LastEditDate             datetime64[ns]
# CommunityOwnedDate       datetime64[ns]
# ParentId                        float64
# ClosedDate               datetime64[ns]
# OwnerDisplayName                 object
# LastEditorDisplayName            object
# dtype: object

# %%
posts.describe()
# Out:
#                   Id    PostTypeId  AcceptedAnswerId         Score  \
# count   91976.000000  91976.000000      14700.000000  91976.000000
# mean    56147.699465      1.568866      52241.702993      2.791902
# std     33975.569431      0.611743      33456.248383      4.981867
# min         1.000000      1.000000          5.000000    -19.000000
# 25%     25489.750000      1.000000      22065.250000      1.000000
# 50%     56781.500000      2.000000      49804.500000      2.000000
# 75%     85909.250000      2.000000      80419.250000      3.000000
# max    115378.000000      7.000000     115345.000000    192.000000
#
#            ViewCount   OwnerUserId   AnswerCount  CommentCount  FavoriteCount  \
# count   42921.000000  90584.000000  42921.000000  91976.000000   13246.000000
# mean      565.746022  16546.764727      1.112626      1.895114       2.543485
# std      2449.796066  15273.367108      1.490570      2.639020       5.919266
# min         1.000000     -1.000000      0.000000      0.000000       0.000000
# 25%        53.000000   3437.000000      0.000000      0.000000       1.000000
# 50%       128.000000  11032.000000      1.000000      1.000000       1.000000
# 75%       373.000000  27700.000000      2.000000      3.000000       2.000000
# max    175495.000000  55746.000000    136.000000     45.000000     233.000000
#
#        LastEditorUserId      ParentId
# count      44611.000000   47755.00000
# mean       11923.021295   48358.27840
# std        13392.705758   34091.46136
# min           -1.000000       1.00000
# 25%          919.000000   17558.00000
# 50%         7290.000000   44790.00000
# 75%        21846.000000   77059.50000
# max        55733.000000  115375.00000

# %% [markdown]
# # Challenge 2 - Prepare the Datasets for Merging and Merge
#
# #### We would like to join a subset of columns from each table. To ease the process, let's create a new dataframe containing a subset of columns for both `posts` and `users`
#
# In the cell below, create a new dataframe called `posts_subset` containing only the columns: `Id`, `Score`, `OwnerUserID`, `ViewCount` ,`CommentCount`

# %%
posts_subset = posts[['Id','Score','OwnerUserId','ViewCount','CommentCount']]
posts_subset
# Out:
#            Id  Score  OwnerUserId  ViewCount  CommentCount
# 0           1     23          8.0     1278.0             1
# 1           2     22         24.0     8198.0             1
# 2           3     54         18.0     3613.0             4
# 3           4     13         23.0     5224.0             2
# 4           5     81         23.0        NaN             3
# ...       ...    ...          ...        ...           ...
# 91971  115374      2        805.0        NaN             2
# 91972  115375      0      49365.0        9.0             0
# 91973  115376      1      55746.0        5.0             2
# 91974  115377      0        805.0        NaN             0
# 91975  115378      0       7250.0        NaN             0
#
# [91976 rows x 5 columns]

# %% [markdown]
# In the cell below, create a dataframe called `users_subset` containing only the columns `Id`, `Reputation`, `Views`, `UpVotes`, `DownVotes`.

# %%
users_subset = users[['Id','Reputation','Views','UpVotes','DownVotes']]

users_subset
# Out:
#           Id  Reputation  Views  UpVotes  DownVotes
# 0         -1           1      0     5007       1920
# 1          2         101     25        3          0
# 2          3         101     22       19          0
# 3          4         101     11        0          0
# 4          5        6792   1145      662          5
# ...      ...         ...    ...      ...        ...
# 40320  55743           1      0        0          0
# 40321  55744           6      1        0          0
# 40322  55745         101      0        0          0
# 40323  55746         106      1        0          0
# 40324  55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %% [markdown]
# #### You will note that the Id column does not refer to the same thing in both tables. In the posts table, it refers to the post ID and in the users table it refers to the user ID.
#
# In the `users_subset` dataframe, rename the `Id` column to `UserId`. Do this using the option `inplace=True`.

# %%
users_subset.rename(columns={'Id':'UserId'},inplace=True)
# Out:
# C:\Users\asomm\anaconda3\envs\excondables\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# In the `posts_subset` dataframe, rename the `Id` column to `PostId`. Do this using the option `inplace=True`.

# %%
posts_subset.rename(columns={'Id':'PostId'},inplace=True)

# %% [markdown]
# We identify the only column that the two tables have in common as the user ID. However, this column is called `UserId` in the `users_subset` table and `OwnerUserId` in the `posts_subset` table. Using what we have previously learned about merging two dataframes and looking at the documentation [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html), merge the two dataframes. Name the merged dataframe `stackoverflow`.

# %%
stackoverflow = users_subset.merge(posts_subset, left_on = "UserId", right_on = "OwnerUserId", suffixes=('_user','_post'))

          
stackoverflow
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90579   55734           1      0        0          0  115352      0
# 90580   55738          11      0        0          0  115360      2
# 90581   55742           6      0        0          0  115366      1
# 90582   55744           6      1        0          0  115370      1
# 90583   55746         106      1        0          0  115376      1
#
#        OwnerUserId  ViewCount  CommentCount
# 0             -1.0        NaN             0
# 1             -1.0        NaN             0
# 2             -1.0        NaN             0
# 3             -1.0        NaN             0
# 4             -1.0        NaN             0
# ...            ...        ...           ...
# 90579      55734.0       16.0             0
# 90580      55738.0       40.0             4
# 90581      55742.0       17.0             0
# 90582      55744.0       13.0             2
# 90583      55746.0        5.0             2
#
# [90584 rows x 10 columns]

# %% [markdown]
# Check to see if you have kept both key columns (if you join by making one of the columns an index first, this can be avoided).
#
# If both columns are present in `stackoverflow`, drop `OwnerUserId`. Do this using `inplace=True`.

# %%
stackoverflow.drop(['OwnerUserId'],inplace = True,axis =1)
stackoverflow
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90579   55734           1      0        0          0  115352      0
# 90580   55738          11      0        0          0  115360      2
# 90581   55742           6      0        0          0  115366      1
# 90582   55744           6      1        0          0  115370      1
# 90583   55746         106      1        0          0  115376      1
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90579       16.0             0
# 90580       40.0             4
# 90581       17.0             0
# 90582       13.0             2
# 90583        5.0             2
#
# [90584 rows x 9 columns]

# %% [markdown]
# # Challenge 3 - Cleaning Up the Data
#
# Now that we have merged the two dataframes, let's handle the missing values.
#
# Find the number of missing values in each column by applying the `isna()` function to the dataframe. Then apply the `sum()` function to that to find the count of missing values in each column.

# %%
stackoverflow.isna().sum()
# Out:
# UserId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# PostId              0
# Score               0
# ViewCount       48396
# CommentCount        0
# dtype: int64

# %% [markdown]
# We see that about half of all observations in the view count column are missing. Let's examine these observations and why they have missing data. Create a subset of rows that have a missing value in the `ViewCount`. Look at the `describe()` function for that subset.

# %%
nullrows = stackoverflow[stackoverflow['ViewCount'].isna()]
nullrows
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90518   55605           1      2        0          0  115106      0
# 90521   55609           1      1        0          0  115115      2
# 90528   55621           1      1        0          0  115213      0
# 90536   55637          26      4        0          0  115170      1
# 90575   55729          16      1        0          0  115338      0
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90518        NaN             0
# 90521        NaN             0
# 90528        NaN             0
# 90536        NaN             0
# 90575        NaN             0
#
# [48396 rows x 9 columns]

# %% [markdown]
# It seems that there is a mix of users. They do not have a high comment count but they do have some upvotes and downvotes. Therefore, it would not make sense to fill these values with zero.
#
# If we investigate further, we will see that there are some users that have view counts missing for some posts but not others. We will cover different ways of investigating further in future lessons. What we can certainly say is that we should not fill all cells with the same values. One way to fill the values is using linear interpolation. Linear interpolation assumes that there is a line between two points and places all observations between the two points along that line. You can read more about linear interpolation [here](https://en.wikipedia.org/wiki/Linear_interpolation).
#
# To apply linear interpolation to our missing data, we use the `interpolate` function in pandas. You can read the documentation for this function [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html).
#
# Apply the `interpolate` function to the `ViewCount` column. Use `inplace=True`

# %%
stackoverflow['ViewCount'].interpolate(method='linear',inplace =True)

# %%
stackoverflow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90584 entries, 0 to 90583
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UserId        90584 non-null  int64
#  1   Reputation    90584 non-null  int64
#  2   Views         90584 non-null  int64
#  3   UpVotes       90584 non-null  int64
#  4   DownVotes     90584 non-null  int64
#  5   PostId        90584 non-null  int64
#  6   Score         90584 non-null  int64
#  7   ViewCount     90373 non-null  float64
#  8   CommentCount  90584 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 6.9 MB

# %%
#We will try to shuffle the data to see if we can make the interpolation work better:
stackoverflow = stackoverflow.sample(frac=1)
stackoverflow
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 79600   38206         670     42       59          1   85663      1
# 9265      805       65272   5680     7035        143   61849     14
# 16866    1973         387     74       18          0    5271      1
# 7544      686       44152   7357     2156         82   59506      0
# 21322    3158          23      2        7          0    7102      4
# ...       ...         ...    ...      ...        ...     ...    ...
# 71206   29579          11      2        0          0   68417      2
# 21325    3172          46     12        3          0   10366      1
# 81934   41816          16      0        0          0   89799      3
# 68097   27790           6      0        0          0   63720      1
# 88554   52537          13      1        0          0  108851      2
#
#          ViewCount  CommentCount
# 79600   100.000000             0
# 9265   1907.347352             0
# 16866  3993.000000             0
# 7544    131.219178             0
# 21322   590.000000             2
# ...            ...           ...
# 71206    91.000000             5
# 21325   959.000000             1
# 81934   103.000000             0
# 68097    39.000000             1
# 88554    15.000000             0
#
# [90584 rows x 9 columns]

# %%
stackoverflow['ViewCount'].interpolate(method='linear',inplace =True)
#It worked!

# %%
stackoverflow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90584 entries, 79600 to 88554
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UserId        90584 non-null  int64
#  1   Reputation    90584 non-null  int64
#  2   Views         90584 non-null  int64
#  3   UpVotes       90584 non-null  int64
#  4   DownVotes     90584 non-null  int64
#  5   PostId        90584 non-null  int64
#  6   Score         90584 non-null  int64
#  7   ViewCount     90584 non-null  float64
#  8   CommentCount  90584 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 6.9 MB

# %% [markdown]
# ### Alternative method and bonus challenge - Fill the Missing Data Using Linear Regression
# We have learned about linear regression in the prework. To read more about linear regression in Python, click [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).
#
# Create a linear model where the Y variable is the `ViewCount` and the X variable is `Score`. Make sure to use only rows that do not contain `NaN` by filtering them out.
#
# Use this regression model to produce a fitted value for every `NaN`. Using the `np.where` function, assign the predicted value only to rows where you have a `NaN`.
#
# Tip: If you get an error when creating your linear model, reshape the data to the correct shape (a 2D array) by appending `.values.reshape(-1, 1)` to the column. Also, transform the predicted data from a numpy array back to a dataframe and use only one column.

# %%
#we recall the dataframe that has all those missing values
stackoverflow2 = users_subset.merge(posts_subset, left_on = "UserId", right_on = "OwnerUserId", suffixes=('_user','_post'))

# %%
#we take only the ones that dont miss viewcount data
trainer = stackoverflow2[stackoverflow2['ViewCount'].notna()]

# %%
#import the model
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
#Separating by categories
X = trainer[['Score']]
y = trainer['ViewCount']

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=100)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
stackoverflow2.sample(10)
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 35671    7600          55     10        2          0   18917      8
# 40073    8927        1354    430      100          5   45933      0
# 64942   25433        3680    344      608         30   63451      0
# 8767      805       65272   5680     7035        143   41653      2
# 62402   23597           4      0        0          0   54472      0
# 15679    1679        3536    382      164          8    4567     74
# 87798   49471          28      0        1          0  105729      3
# 25101    4344          87     53        2          0   43767      0
# 59284   20921          64      8       10          0   50982      4
# 75483   34695         146      3        0          0   86453      0
#
#        OwnerUserId  ViewCount  CommentCount
# 35671       7600.0      286.0             0
# 40073       8927.0      260.0             0
# 64942      25433.0        NaN             0
# 8767         805.0        NaN             0
# 62402      23597.0     2748.0             1
# 15679       1679.0        NaN             9
# 87798      49471.0       39.0             3
# 25101       4344.0       17.0             0
# 59284      20921.0       83.0             1
# 75483      34695.0       75.0             5

# %%
stackoverflow2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90584 entries, 0 to 90583
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UserId        90584 non-null  int64
#  1   Reputation    90584 non-null  int64
#  2   Views         90584 non-null  int64
#  3   UpVotes       90584 non-null  int64
#  4   DownVotes     90584 non-null  int64
#  5   PostId        90584 non-null  int64
#  6   Score         90584 non-null  int64
#  7   OwnerUserId   90584 non-null  float64
#  8   ViewCount     42188 non-null  float64
#  9   CommentCount  90584 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 7.6 MB

# %%
stackoverflow2['ViewCount'] = np.where(stackoverflow2['ViewCount'].isna(), lm.predict(stackoverflow2[['Score']]), stackoverflow2['ViewCount'])

# %%
#The model ended up having around 10% of the viewcounts in negative, one reason could be due to negative or zero score?
stackoverflow2[stackoverflow2['ViewCount']<0]
# Out:
#        UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90506   55588           1      1        0          0  115075      0
# 90513   55599          31      2        0          0  115233      0
# 90518   55605           1      2        0          0  115106      0
# 90528   55621           1      1        0          0  115213      0
# 90575   55729          16      1        0          0  115338      0
#
#        OwnerUserId  ViewCount  CommentCount
# 0             -1.0 -99.999187             0
# 1             -1.0 -99.999187             0
# 2             -1.0 -99.999187             0
# 3             -1.0 -99.999187             0
# 4             -1.0 -99.999187             0
# ...            ...        ...           ...
# 90506      55588.0 -99.999187             0
# 90513      55599.0 -99.999187             0
# 90518      55605.0 -99.999187             0
# 90528      55621.0 -99.999187             0
# 90575      55729.0 -99.999187             0
#
# [9144 rows x 10 columns]

# %%
# so we will stick to the original stackoverflow dataframe

# %% [markdown]
# We have seen that both `UserId` and `PostsId` are treated as numeric even though they do not describe anything quantitative about the data. We would like to exclude them from any numeric calculations. To do this, we should change them from numeric to string. Transform each column from numeric to string using the `astype` function and pass the argument `'str'` to the function. Since we cannot do this in place, assign these new values back to their original column names.

# %%
stackoverflow=stackoverflow.astype({'UserId':'str','PostId':'str'})
stackoverflow.dtypes
# Out:
# UserId           object
# Reputation        int64
# Views             int64
# UpVotes           int64
# DownVotes         int64
# PostId           object
# Score             int64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %% [markdown]
# #### More clean steps - example : We would like to simplify the comment count variable by bucketing this variable.
#
# In the cell below, we have created 5 bins. Bucket this variable into equal width bins using the `cut` function. Create a new column called `CommentBins` and assign the bucketed data to this column
# other clean steps you could consider - identifying and removing outliers, renaming columns to more obvious labels, drop useless columns, specify axis, concat or split columns, filter by a logical range of dates, standardise the case, use string functions to limit/ standardise the values... there are other potential steps, you will need to use your judgement to work out when the data is "clean" enough to output!

# %%
#comment_labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
# Your code here:

stackoverflow.describe()
# Out:
#          Reputation         Views       UpVotes     DownVotes         Score  \
# count  90584.000000  90584.000000  90584.000000  90584.000000  90584.000000
# mean    6282.395412   1034.245176    734.315718     33.273249      2.780767
# std    15102.268670   2880.074012   2050.869327    134.936435      4.948922
# min        1.000000      0.000000      0.000000      0.000000    -19.000000
# 25%       60.000000      5.000000      1.000000      0.000000      1.000000
# 50%      396.000000     45.000000     22.000000      0.000000      2.000000
# 75%     4460.000000    514.250000    283.000000      8.000000      3.000000
# max    87393.000000  20932.000000  11442.000000   1920.000000    192.000000
#
#            ViewCount  CommentCount
# count   90584.000000  90584.000000
# mean      740.028657      1.894650
# std      2454.685904      2.638704
# min         1.000000      0.000000
# 25%        83.000000      0.000000
# 50%       225.000000      1.000000
# 75%       637.433824      3.000000
# max    175495.000000     45.000000

# %%
#I want to add a row that tells how many times the user have posted
#We first make a dictionary with the userID as keys and the number of rows(posts) as values
views = stackoverflow['UserId'].value_counts().to_dict()
# Out:
# {'805': 1720,
#  '686': 1598,
#  '919': 1204,
#  '11032': 966,
#  '7290': 827,
#  '4505': 661,
#  '183': 493,
#  '930': 458,
#  '4253': 450,
#  '3382': 425,
#  '28746': 417,
#  '5739': 397,
#  '7828': 388,
#  '601': 380,
#  '887': 367,
#  '2116': 363,
#  '22047': 345,
#  '7972': 340,
#  '88': 339,
#  '2392': 321,
#  '8013': 320,
#  '159': 293,
#  '1005': 292,
#  '2669': 291,
#  '17230': 290,
#  '3277': 286,
#  '2958': 277,
#  '2817': 276,
#  '7071': 274,
#  '32036': 269,
#  '4856': 266,
#  '5836': 265,
#  '449': 260,
#  '603': 258,
#  '4598': 254,
#  '1764': 252,
#  '7555': 234,
#  '9394': 227,
#  '795': 225,
#  '44269': 213,
#  '-1': 211,
#  '6633': 210,
#  '8402': 206,
#  '26338': 191,
#  '23853': 190,
#  '196': 188,
#  '1036': 187,
#  '1739': 182,
#  '253': 180,
#  '36041': 179,
#  '401': 172,
#  '4257': 168,
#  '1390': 167,
#  '10849': 163,
#  '2040': 163,
#  '1352': 160,
#  '279': 158,
#  '25433': 157,
#  '6029': 155,
#  '21599': 154,
#  '17908': 153,
#  '7250': 149,
#  '22468': 147,
#  '14188': 147,
#  '12329': 146,
#  '364': 144,
#  '13138': 142,
#  '25': 137,
#  '251': 132,
#  '22452': 132,
#  '3019': 132,
#  '442': 131,
#  '2860': 127,
#  '264': 126,
#  '13047': 123,
#  '8': 121,
#  '5': 117,
#  '8451': 115,
#  '4376': 115,
#  '7224': 115,
#  '11981': 114,
#  '2129': 111,
#  '11887': 111,
#  '2310': 106,
#  '12492': 106,
#  '6961': 105,
#  '5862': 105,
#  '892': 105,
#  '11852': 104,
#  '21054': 103,
#  '17661': 101,
#  '1679': 101,
#  '8605': 101,
#  '17359': 99,
#  '858': 99,
#  '8076': 97,
#  '223': 94,
#  '2970': 94,
#  '1381': 92,
#  '3911': 91,
#  '22311': 91,
#  '1909': 91,
#  '1307': 90,
#  '31668': 87,
#  '6096': 85,
#  '28666': 85,
#  '5509': 84,
#  '10524': 83,
#  '2798': 83,
#  '16049': 83,
#  '14803': 83,
#  '1569': 82,
#  '11867': 80,
#  '52554': 79,
#  '14860': 79,
#  '334': 78,
#  '44965': 77,
#  '4862': 76,
#  '12603': 76,
#  '28740': 75,
#  '7365': 75,
#  '17072': 75,
#  '1934': 74,
#  '36229': 74,
#  '9007': 74,
#  '30351': 74,
#  '74': 73,
#  '9162': 73,
#  '14730': 73,
#  '2126': 72,
#  '3262': 72,
#  '8507': 72,
#  '28732': 72,
#  '1329': 71,
#  '3919': 71,
#  '36540': 71,
#  '27581': 70,
#  '21998': 70,
#  '656': 68,
#  '5405': 68,
#  '14434': 68,
#  '31420': 67,
#  '8141': 67,
#  '3903': 67,
#  '5339': 67,
#  '2775': 67,
#  '34658': 66,
#  '8137': 66,
#  '3601': 66,
#  '582': 65,
#  '7616': 65,
#  '11748': 64,
#  '8580': 64,
#  '27779': 64,
#  '24073': 64,
#  '16709': 63,
#  '307': 62,
#  '5429': 61,
#  '4479': 61,
#  '339': 61,
#  '8413': 60,
#  '3567': 59,
#  '1191': 59,
#  '26': 59,
#  '44451': 58,
#  '7497': 58,
#  '7795': 58,
#  '2645': 58,
#  '3748': 57,
#  '8207': 57,
#  '6248': 57,
#  '9174': 57,
#  '3874': 57,
#  '11030': 57,
#  '27403': 57,
#  '13818': 56,
#  '29137': 56,
#  '29617': 56,
#  '25212': 56,
#  '36462': 56,
#  '1106': 56,
#  '37976': 56,
#  '226': 56,
#  '37188': 55,
#  '1709': 54,
#  '6547': 54,
#  '20776': 54,
#  '19879': 54,
#  '24669': 54,
#  '6897': 53,
#  '9568': 53,
#  '3468': 52,
#  '13636': 52,
#  '521': 52,
#  '588': 52,
#  '24617': 52,
#  '13634': 51,
#  '6768': 51,
#  '3310': 51,
#  '5829': 51,
#  '439': 50,
#  '36545': 50,
#  '25392': 50,
#  '24515': 49,
#  '1124': 49,
#  '35099': 49,
#  '3269': 49,
#  '2921': 48,
#  '6920': 48,
#  '4812': 48,
#  '16297': 48,
#  '24097': 48,
#  '4496': 48,
#  '2164': 48,
#  '10500': 48,
#  '48148': 48,
#  '666': 48,
#  '28705': 48,
#  '273': 48,
#  '6446': 48,
#  '11623': 47,
#  '21846': 47,
#  '20381': 47,
#  '10026': 47,
#  '25936': 47,
#  '31334': 47,
#  '2676': 47,
#  '776': 47,
#  '16663': 46,
#  '2719': 46,
#  '11849': 46,
#  '10354': 46,
#  '49398': 46,
#  '2485': 46,
#  '10064': 46,
#  '495': 46,
#  '35736': 46,
#  '54099': 46,
#  '16859': 45,
#  '29068': 45,
#  '8927': 45,
#  '10069': 45,
#  '27556': 45,
#  '557': 44,
#  '6082': 44,
#  '28524': 44,
#  '36539': 43,
#  '8114': 43,
#  '18459': 43,
#  '333': 43,
#  '1108': 43,
#  '485': 43,
#  '28566': 43,
#  '7788': 43,
#  '2728': 43,
#  '199': 42,
#  '1913': 42,
#  '16175': 42,
#  '8101': 42,
#  '10619': 42,
#  '3411': 42,
#  '179': 42,
#  '24808': 42,
#  '2074': 42,
#  '10598': 42,
#  '12147': 41,
#  '13519': 41,
#  '5256': 41,
#  '144': 41,
#  '17812': 41,
#  '30201': 41,
#  '44764': 41,
#  '8120': 41,
#  '36381': 40,
#  '11091': 40,
#  '71': 40,
#  '44760': 40,
#  '17672': 40,
#  '40124': 40,
#  '26105': 40,
#  '22': 39,
#  '14741': 39,
#  '13516': 39,
#  '8783': 39,
#  '8200': 39,
#  '30': 39,
#  '561': 39,
#  '5264': 39,
#  '29087': 38,
#  '1118': 38,
#  '1080': 38,
#  '3488': 38,
#  '511': 38,
#  '14346': 38,
#  '21961': 38,
#  '12710': 38,
#  '40023': 38,
#  '1808': 38,
#  '696': 38,
#  '12833': 37,
#  '14289': 37,
#  '9136': 37,
#  '1893': 37,
#  '3058': 37,
#  '9738': 37,
#  '9975': 37,
#  '21240': 37,
#  '16765': 36,
#  '1146': 36,
#  '10823': 36,
#  '13680': 36,
#  '7411': 36,
#  '28462': 36,
#  '4829': 36,
#  '966': 36,
#  '4495': 36,
#  '9964': 36,
#  '6129': 36,
#  '319': 35,
#  '21072': 35,
#  '230': 35,
#  '11878': 35,
#  '28903': 35,
#  '16811': 35,
#  '10389': 35,
#  '4559': 35,
#  '5837': 35,
#  '1540': 35,
#  '14857': 35,
#  '25973': 35,
#  '12436': 35,
#  '20884': 34,
#  '3125': 34,
#  '8165': 34,
#  '36771': 34,
#  '215': 34,
#  '7733': 34,
#  '21654': 34,
#  '6489': 34,
#  '6552': 34,
#  '24498': 34,
#  '3331': 34,
#  '10416': 33,
#  '21720': 33,
#  '14836': 33,
#  '5191': 33,
#  '2150': 33,
#  '7244': 33,
#  '16974': 33,
#  '5792': 33,
#  '8871': 32,
#  '1443': 32,
#  '9343': 32,
#  '5494': 32,
#  '29187': 32,
#  '31264': 32,
#  '35572': 32,
#  '7787': 32,
#  '900': 32,
#  '13702': 32,
#  '11475': 32,
#  '3489': 32,
#  '2425': 32,
#  '11060': 32,
#  '11639': 31,
#  '4426': 31,
#  '18128': 31,
#  '29433': 31,
#  '6000': 31,
#  '20556': 31,
#  '4485': 31,
#  '39953': 31,
#  '266': 31,
#  '4673': 31,
#  '30540': 31,
#  '28288': 31,
#  '32397': 31,
#  '22543': 31,
#  '40967': 30,
#  '18528': 30,
#  '7486': 30,
#  '27213': 30,
#  '9253': 30,
#  '12359': 30,
#  '8067': 30,
#  '1513': 30,
#  '1499': 30,
#  '1763': 30,
#  '11708': 30,
#  '6637': 30,
#  '11242': 29,
#  '52432': 29,
#  '4278': 29,
#  '17096': 29,
#  '37483': 29,
#  '36': 29,
#  '59': 29,
#  '16596': 29,
#  '43534': 28,
#  '28545': 28,
#  '10479': 28,
#  '41260': 28,
#  '6369': 28,
#  '24905': 28,
#  '30460': 28,
#  '4337': 28,
#  '28183': 28,
#  '9013': 28,
#  '24000': 28,
#  '11405': 28,
#  '2750': 28,
#  '48766': 28,
#  '1945': 28,
#  '4908': 28,
#  '8006': 27,
#  '12265': 27,
#  '38206': 27,
#  '24341': 27,
#  '13561': 27,
#  '1347': 27,
#  '3835': 27,
#  '11279': 27,
#  '12895': 27,
#  '8109': 27,
#  '2898': 27,
#  '12923': 27,
#  '1119': 27,
#  '14163': 27,
#  '4290': 27,
#  '6884': 27,
#  '28218': 27,
#  '7690': 26,
#  '10322': 26,
#  '38348': 26,
#  '19815': 26,
#  '13154': 26,
#  '190': 26,
#  '609': 26,
#  '14104': 26,
#  '1496': 26,
#  '14731': 26,
#  '8724': 26,
#  '26206': 26,
#  '8960': 26,
#  '6666': 26,
#  '53057': 26,
#  '881': 26,
#  '20980': 26,
#  '22314': 26,
#  '17590': 26,
#  '1670': 25,
#  '31221': 25,
#  '44023': 25,
#  '4754': 25,
#  '27765': 25,
#  '46522': 25,
#  '8320': 25,
#  '14675': 25,
#  '16612': 25,
#  '5464': 25,
#  '438': 25,
#  '1643': 25,
#  '35131': 25,
#  '6434': 25,
#  '40252': 25,
#  '11954': 25,
#  '30417': 25,
#  '18563': 24,
#  '22062': 24,
#  '5795': 24,
#  '25944': 24,
#  '6432': 24,
#  '12318': 24,
#  '82': 24,
#  '8686': 24,
#  '3293': 24,
#  '10675': 24,
#  '29600': 24,
#  '247': 24,
#  '3572': 24,
#  '36680': 24,
#  '1977': 24,
#  '54300': 24,
#  '2488': 24,
#  '8694': 24,
#  '3582': 24,
#  '10017': 24,
#  '7734': 24,
#  '4701': 24,
#  '7918': 24,
#  '61': 23,
#  '18152': 23,
#  '16989': 23,
#  '9171': 23,
#  '31774': 23,
#  '14826': 23,
#  '5594': 23,
#  '996': 23,
#  '31261': 23,
#  '4581': 23,
#  '1351': 23,
#  '10119': 23,
#  '18334': 23,
#  '5321': 23,
#  '30951': 23,
#  '7064': 23,
#  '35917': 23,
#  '287': 23,
#  '28309': 23,
#  '12548': 23,
#  '7199': 23,
#  '4344': 23,
#  '8242': 23,
#  '44795': 23,
#  '16837': 23,
#  '10776': 23,
#  '11805': 23,
#  '14888': 23,
#  '19762': 22,
#  '3432': 22,
#  '1098': 22,
#  '6723': 22,
#  '25184': 22,
#  '6072': 22,
#  '29109': 22,
#  '4110': 22,
#  '8539': 22,
#  '20148': 22,
#  '1291': 22,
#  '18274': 22,
#  '25133': 22,
#  '41389': 22,
#  '25692': 22,
#  '8373': 22,
#  '12719': 22,
#  '10217': 22,
#  '13804': 22,
#  '26267': 22,
#  '26357': 22,
#  '29943': 22,
#  '3805': 22,
#  '23801': 22,
#  '2592': 21,
#  '34874': 21,
#  '29021': 21,
#  '6479': 21,
#  '19848': 21,
#  '2849': 21,
#  '43634': 21,
#  '29537': 21,
#  '5176': 21,
#  '8762': 21,
#  '961': 21,
#  '32504': 21,
#  '3369': 21,
#  '31104': 21,
#  '4733': 21,
#  '3794': 21,
#  '4864': 21,
#  '6845': 21,
#  '5280': 21,
#  '28520': 21,
#  '14156': 21,
#  '2111': 21,
#  '24137': 21,
#  '17046': 21,
#  '9595': 21,
#  '17124': 21,
#  '4872': 21,
#  '27838': 21,
#  '101': 21,
#  '12752': 21,
#  '36068': 21,
#  '30438': 20,
#  '12518': 20,
#  '8196': 20,
#  '5832': 20,
#  '31611': 20,
#  '847': 20,
#  '38102': 20,
#  '30815': 20,
#  '13902': 20,
#  '39531': 20,
#  '1048': 20,
#  '13950': 20,
#  '49130': 20,
#  '16137': 20,
#  '28500': 20,
#  '35398': 20,
#  '30395': 20,
#  '862': 20,
#  '5864': 20,
#  '48639': 20,
#  '14125': 20,
#  '7397': 20,
#  '46925': 20,
#  '2546': 20,
#  '22022': 20,
#  '6720': 20,
#  '6793': 20,
#  '8226': 20,
#  '29183': 20,
#  '1818': 20,
#  '49279': 20,
#  '8205': 20,
#  '40761': 20,
#  '21972': 20,
#  '18268': 20,
#  '2660': 20,
#  '20085': 19,
#  '3595': 19,
#  '5546': 19,
#  '1979': 19,
#  '12786': 19,
#  '20917': 19,
#  '14525': 19,
#  '3525': 19,
#  '29500': 19,
#  '6476': 19,
#  '9146': 19,
#  '1573': 19,
#  '12521': 19,
#  '43653': 19,
#  '16640': 19,
#  '56': 19,
#  '13038': 19,
#  '10630': 19,
#  '16939': 19,
#  '11843': 19,
#  '6015': 19,
#  '1549': 19,
#  '17286': 19,
#  '37632': 19,
#  '25675': 19,
#  '12626': 19,
#  '3026': 19,
#  '8662': 19,
#  '139': 19,
#  '704': 19,
#  '9249': 18,
#  '12008': 18,
#  '30701': 18,
#  '4751': 18,
#  '32181': 18,
#  '10749': 18,
#  '12540': 18,
#  '18164': 18,
#  '9887': 18,
#  '31466': 18,
#  '812': 18,
#  '3077': 18,
#  '6579': 18,
#  '9426': 18,
#  '31152': 18,
#  '6828': 18,
#  '6649': 18,
#  '7883': 18,
#  '12005': 18,
#  '11984': 18,
#  '198': 18,
#  '35224': 18,
#  '3280': 18,
#  '32472': 18,
#  '1356': 18,
#  '28281': 18,
#  '54013': 18,
#  '13022': 18,
#  '25335': 18,
#  '10908': 18,
#  '12793': 18,
#  '5289': 18,
#  '32299': 18,
#  '36785': 18,
#  '41307': 18,
#  '9671': 18,
#  '1270': 17,
#  '44469': 17,
#  '30192': 17,
#  '8041': 17,
#  '29374': 17,
#  '2073': 17,
#  '4164': 17,
#  '5480': 17,
#  '15978': 17,
#  '31372': 17,
#  '27576': 17,
#  '27330': 17,
#  '31160': 17,
#  '3376': 17,
#  '13525': 17,
#  '14843': 17,
#  '17463': 17,
#  '2981': 17,
#  '13555': 17,
#  '29911': 17,
#  '1050': 17,
#  '36575': 17,
#  '30494': 17,
#  '36564': 17,
#  '40494': 17,
#  '31135': 17,
#  '30557': 17,
#  '7339': 17,
#  '45876': 17,
#  '10530': 17,
#  '4843': 17,
#  '3807': 17,
#  '28835': 17,
#  '9177': 17,
#  '6946': 17,
#  '29825': 17,
#  '7255': 17,
#  '36682': 17,
#  '42952': 17,
#  '2956': 17,
#  '3591': 17,
#  '16127': 17,
#  '12258': 17,
#  '6640': 16,
#  '14411': 16,
#  '5003': 16,
#  '21030': 16,
#  '13409': 16,
#  '3640': 16,
#  '873': 16,
#  '3248': 16,
#  '41810': 16,
#  '4329': 16,
#  '4048': 16,
#  '21967': 16,
#  '4238': 16,
#  '5729': 16,
#  '172': 16,
#  '6844': 16,
#  '221': 16,
#  '27840': 16,
#  '22356': 16,
#  '30623': 16,
#  '3265': 16,
#  '2635': 16,
#  '2456': 16,
#  '25292': 16,
#  '36465': 16,
#  '569': 16,
#  '14463': 16,
#  '114': 16,
#  '18549': 16,
#  '16557': 16,
#  '6355': 16,
#  '23840': 16,
#  '315': 16,
#  '30712': 16,
#  '27495': 16,
#  '23759': 16,
#  '4916': 16,
#  '7172': 16,
#  '27915': 16,
#  '3014': 16,
#  '12431': 16,
#  '13212': 16,
#  '12031': 16,
#  '10065': 15,
#  '25074': 15,
#  '8676': 15,
#  '35026': 15,
#  '6877': 15,
#  '36115': 15,
#  '7644': 15,
#  '4737': 15,
#  '5111': 15,
#  '36915': 15,
#  '40582': 15,
#  '3401': 15,
#  '1219': 15,
#  '2902': 15,
#  '6577': 15,
#  '9342': 15,
#  '41856': 15,
#  '40440': 15,
#  '20587': 15,
#  '18287': 15,
#  '7556': 15,
#  '10286': 15,
#  '22414': 15,
#  '22392': 15,
#  '7744': 15,
#  '16843': 15,
#  '976': 15,
#  '39663': 15,
#  '20112': 15,
#  '52672': 15,
#  '26091': 15,
#  '352': 15,
#  '13669': 15,
#  '21160': 15,
#  '22088': 15,
#  '5503': 15,
#  '11511': 15,
#  '3681': 15,
#  '8991': 15,
#  '4769': 15,
#  '27813': 15,
#  '35370': 15,
#  '39588': 15,
#  '31505': 15,
#  '830': 15,
#  '7482': 15,
#  '2704': 15,
#  '32398': 14,
#  '28916': 14,
#  '9244': 14,
#  '26950': 14,
#  '10914': 14,
#  '493': 14,
#  '18215': 14,
#  '2046': 14,
#  '12865': 14,
#  '1250': 14,
#  '4054': 14,
#  '9677': 14,
#  '25386': 14,
#  '39': 14,
#  '34817': 14,
#  '27693': 14,
#  '18493': 14,
#  '27433': 14,
#  '13158': 14,
#  '17481': 14,
#  '8447': 14,
#  '20211': 14,
#  '15997': 14,
#  '27099': 14,
#  '11756': 14,
#  '36738': 14,
#  '28825': 14,
#  '17112': 14,
#  '16949': 14,
#  '14556': 14,
#  '3330': 14,
#  '52022': 14,
#  '5919': 14,
#  '27158': 14,
#  '7515': 14,
#  '43560': 14,
#  '36854': 14,
#  '10210': 14,
#  '12647': 14,
#  '6281': 14,
#  '37148': 14,
#  '11409': 14,
#  '1126': 14,
#  '4045': 14,
#  '845': 14,
#  '229': 14,
#  '12737': 14,
#  '8515': 14,
#  '1657': 14,
#  '21521': 14,
#  '1112': 14,
#  '778': 14,
#  '20015': 13,
#  '29070': 13,
#  '19814': 13,
#  '10760': 13,
#  '31843': 13,
#  '17383': 13,
#  '9203': 13,
#  '23891': 13,
#  '7127': 13,
#  '6725': 13,
#  '300': 13,
#  '8807': 13,
#  '447': 13,
#  '5020': 13,
#  '14845': 13,
#  '21260': 13,
#  '32089': 13,
#  '994': 13,
#  '35753': 13,
#  '10164': 13,
#  '9330': 13,
#  '13564': 13,
#  '4764': 13,
#  '16365': 13,
#  '13348': 13,
#  '3899': 13,
#  '23956': 13,
#  '6169': 13,
#  '5407': 13,
#  '1766': 13,
#  '3052': 13,
#  '21340': 13,
#  '17192': 13,
#  '40215': 13,
#  '36804': 13,
#  '2020': 13,
#  '48490': 13,
#  '52429': 13,
#  '1991': 13,
#  '22518': 13,
#  '5025': 13,
#  '24671': 13,
#  '3454': 13,
#  '3040': 13,
#  '13538': 13,
#  '9998': 13,
#  '7620': 13,
#  '4325': 13,
#  '20735': 13,
#  '781': 13,
#  '31634': 13,
#  '7968': 13,
#  '17464': 13,
#  '17801': 13,
#  '4127': 13,
#  '13915': 13,
#  '40183': 13,
#  '3309': 13,
#  '16362': 13,
#  '1265': 13,
#  '42728': 13,
#  '5471': 13,
#  '22100': 13,
#  '52': 13,
#  '39544': 13,
#  '15949': 13,
#  '20820': 13,
#  '26140': 13,
#  '27400': 13,
#  '559': 13,
#  '2824': 13,
#  '31379': 13,
#  '10669': 13,
#  '27435': 13,
#  '40120': 13,
#  '1229': 13,
#  '48554': 13,
#  '9651': 13,
#  '8116': 13,
#  '573': 13,
#  '30621': 13,
#  '30016': 12,
#  '187': 12,
#  '2513': 12,
#  '9583': 12,
#  '5738': 12,
#  '45745': 12,
#  '7425': 12,
#  '24848': 12,
#  '29020': 12,
#  '6412': 12,
#  '11453': 12,
#  '13378': 12,
#  '5404': 12,
#  '6301': 12,
#  '217': 12,
#  '5635': 12,
#  '48880': 12,
#  '26356': 12,
#  '31563': 12,
#  '11915': 12,
#  '46228': 12,
#  '11944': 12,
#  '118': 12,
#  '17107': 12,
#  '2912': 12,
#  '6917': 12,
#  '25339': 12,
#  '30613': 12,
#  '6664': 12,
#  '52756': 12,
#  '419': 12,
#  '32377': 12,
#  '31188': 12,
#  '1195': 12,
#  '24721': 12,
#  '43338': 12,
#  '22307': 12,
#  '13362': 12,
#  '9405': 12,
#  '16134': 12,
#  '34645': 12,
#  '20727': 12,
#  '9444': 12,
#  '5419': 12,
#  '25965': 12,
#  '27464': 12,
#  '42668': 12,
#  '110': 12,
#  '12331': 12,
#  '40128': 12,
#  '36303': 12,
#  '13935': 12,
#  '26658': 12,
#  '37928': 12,
#  '13107': 12,
#  '6': 12,
#  '5397': 12,
#  '7169': 12,
#  '87': 12,
#  ...}

# %%
stackoverflow['no_posted'] = [views[str(x)] for x in stackoverflow['UserId']]

# %%
stackoverflow
# Out:
#       UserId  Reputation  Views  UpVotes  DownVotes  PostId  Score  \
# 79600  38206         670     42       59          1   85663      1
# 9265     805       65272   5680     7035        143   61849     14
# 16866   1973         387     74       18          0    5271      1
# 7544     686       44152   7357     2156         82   59506      0
# 21322   3158          23      2        7          0    7102      4
# ...      ...         ...    ...      ...        ...     ...    ...
# 71206  29579          11      2        0          0   68417      2
# 21325   3172          46     12        3          0   10366      1
# 81934  41816          16      0        0          0   89799      3
# 68097  27790           6      0        0          0   63720      1
# 88554  52537          13      1        0          0  108851      2
#
#          ViewCount  CommentCount  no_posted
# 79600   100.000000             0         27
# 9265   1907.347352             0       1720
# 16866  3993.000000             0          8
# 7544    131.219178             0       1598
# 21322   590.000000             2          1
# ...            ...           ...        ...
# 71206    91.000000             5          1
# 21325   959.000000             1          5
# 81934   103.000000             0          1
# 68097    39.000000             1          1
# 88554    15.000000             0          1
#
# [90584 rows x 10 columns]

# %%
stackoverflow['no_posted'].unique()
# Out:
# array([  27, 1720,    8, 1598,    1,   48,   31,   15,  167,  966,   99,
#         146,   11,    5,  277,    2,  276,  367,  291,   64, 1204,   10,
#           4,   25,    6,   16,   83,  180,  105,   58,  397,   77,  417,
#         101,  153,   26,  115,   79,  450,   46,   33,   20,  265,   23,
#           9,  126,   74,  168,   30,   17,    3,   87,  260,   54,  132,
#          38,   14,   13,    7,   35,   12,   29,   32,   42,   94,  182,
#          63,   72,  827,  345,  213,   24,   68,  269,   59,  458,   91,
#         155,  339,   22,   49,  163,  117,  147,   57,  227,   21,  493,
#          43,   62,  266,  290,   61,   45,   28,  292,  210,  142,   36,
#         254,   51,   52,   76,  131,  388,  380,   19,  321,  320,   18,
#         157,   47,  286,   67,  225,   53,  144,  137,  172,   44,  179,
#         258,  187,  114,  363,   37,  206,  340,  106,   75,   71,  425,
#         252,   80,   34,  211,   56,  149,   41,   70,   97,   73,  661,
#          78,  158,  293,  127,   39,  111,  121,  234,   90,   40,  103,
#         274,  188,  191,   92,   65,  160,   50,   55,   84,   66,  190,
#          60,  154,  104,   85,   82,  123], dtype=int64)

# %%
pd.cut(stackoverflow['Score'], bins=5).value_counts()
# Out:
# (-19.211, 23.2]    89923
# (23.2, 65.4]         587
# (65.4, 107.6]         55
# (107.6, 149.8]        14
# (149.8, 192.0]         5
# Name: Score, dtype: int64

# %%
#The bins are too uneven to describe the data, so we will start cleaning out outliers.

# %%
def clean_outliers(data,col):
    """
    Will input the column name as data['Column'], will return the dataframe modified, 
    with all data outside 1.5x the interquartile distance from the median. 
    """
    iqr = np.percentile(data[col],75) - np.percentile(data[col],25)
    upper_limit = np.percentile(data[col],75) + 1.5*iqr
    lower_limit = np.percentile(data[col],25) - 1.5*iqr

    return data[(data[col]>lower_limit) & (data[col]<upper_limit)]

# %%
stackoverflow.shape
# Out:
# (90584, 9)

# %%
#stackoverflow = clean_outliers(stackoverflow,'Views')
#stackoverflow = clean_outliers(stackoverflow,'Reputation')
#stackoverflow = clean_outliers(stackoverflow,'Views')

# %%
stackoverflow.describe()
# Out:
#          Reputation         Views       UpVotes     DownVotes         Score  \
# count  90584.000000  90584.000000  90584.000000  90584.000000  90584.000000
# mean    6282.395412   1034.245176    734.315718     33.273249      2.780767
# std    15102.268670   2880.074012   2050.869327    134.936435      4.948922
# min        1.000000      0.000000      0.000000      0.000000    -19.000000
# 25%       60.000000      5.000000      1.000000      0.000000      1.000000
# 50%      396.000000     45.000000     22.000000      0.000000      2.000000
# 75%     4460.000000    514.250000    283.000000      8.000000      3.000000
# max    87393.000000  20932.000000  11442.000000   1920.000000    192.000000
#
#            ViewCount  CommentCount     no_posted
# count   90584.000000  90584.000000  90584.000000
# mean      740.028657      1.894650    164.690939
# std      2454.685904      2.638704    359.616581
# min         1.000000      0.000000      1.000000
# 25%        83.000000      0.000000      3.000000
# 50%       225.000000      1.000000     19.000000
# 75%       637.433824      3.000000    132.000000
# max    175495.000000     45.000000   1720.000000

# %%
pd.cut(stackoverflow['Score'], bins=5).value_counts()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(17,15))
sns.scatterplot(x='no_posted', y= 'Score',size = 'Score', legend = 0, data = stackoverflow)
# Out:
# <AxesSubplot:xlabel='no_posted', ylabel='Score'>

# %%
stackoverflow[stackoverflow['Views']>20000]['Views'].unique()

# %%
posts[posts['OwnerUserId']== 919]['Body'].iloc[6]

# %% [markdown]
# ###

# %% [markdown]
# # Challenge 4 - Export your data frame as a csv
#
# Export df to a csv file using the `df.to_csv` function, filtered by suitable date range, excluding any columns which are not useful for further analysis

# %%
# Your code here:

# %% [markdown]
# # Challenge 5: Visualise relationships found in the data
#
# At this stage you have options to visualise in your chosen tool, Tableau, Excel, python(matploitlib,seaborn), or Other
#
# **Business Question**: We expect there to be a positive correlation between the number of posts users in our community make with the number of views (median count of views) that their posts receive. This is because users get gradually better at posting over time and actually create their own following. Does the data support this? Is this always the case or are there some unexpected exceptions?
#
# Your plot/ visualisation should have an appropriate title, legend and axis so the meaning is as clear as possible without needing a caption.
#
# **Bonus** - add in other interesting features you have created in your cleaning steps, such as the comment buckets, to your visualisation.

# %%
# (if plotting in python) Your code here:
